# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.plot([4,2,1,45,66],[9,5,1,2,3])
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("First Plot")
plt.show()

# %%
plt.plot([4,2,1,45,66],"r.",markersize=10)
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("First Plot")
plt.show()
